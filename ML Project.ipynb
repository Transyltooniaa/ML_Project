# %% [markdown]
# # Importing Commonly Used Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %% [markdown]
# # Loading the dataset

# %% [markdown]
# ## Training Dataset Dataframes

# %%
df = pd.read_csv('train.csv')
df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       DRIRC89L0T   18  137576      209136          846              26
# 1       TS0FIUNHNU   47   57194        5970          748              30
# 2       I0YR284A1V   26   84328       95065          453               7
# 3       WB1T7NQV8A   53   49795      229582          533             107
# 4       J6GU9M4G1Z   49  115450       22072          840               0
# ...            ...  ...     ...         ...          ...             ...
# 204272  KYS1HKNGGE   40  116623      161673          651              79
# 204273  5MAOH3AOZO   67   62958      189499          460              77
# 204274  5Y9Z6NW29X   62   34372       59645          524              94
# 204275  O51974F566   44  146262      198454          489               7
# 204276  SVGAIO53ZK   36   97844      188593          542               2
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# ## Testing Dataset Dataframes

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#            LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0      CKV34LU7V7   55  112656       92393          581             113
# 1      62KTYNH93J   56   91569      131575          641              54
# 2      JGFUSOIUH7   26   78169       75417          569             105
# 3      4538THBHOX   26   63033       10804          326             118
# 4      DXLNA06JHR   24   29665       21182          662             102
# ...           ...  ...     ...         ...          ...             ...
# 51065  DQRTA8KWGC   51   99473      170353          628              24
# 51066  W0FDMPACG3   29   42016      111314          371              51
# 51067  MA0F4U8ORY   67   88507      142666          731              51
# 51068  6QUH04P7EJ   42  116649      190938          488               6
# 51069  GTCED2IEL9   49   90420       83956          752              73
#
#        NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Feature Exploration

# %% [markdown]
# ### Training Dataset

# %%
list_features = df.columns
print('They are',len(list_features),'features in the training dataset.')
print('----------------')
for f in list_features:
    print('feature:', f, '|| Type:', type(df[f][0]), '|| Example:', df[f][0], '|| number of unique values', len(df[f].unique()) )
# Out:
# They are 18 features in the training dataset.
# ----------------
# feature: LoanID || Type: <class 'str'> || Example: DRIRC89L0T || number of unique values 204277
# feature: Age || Type: <class 'numpy.int64'> || Example: 18 || number of unique values 52
# feature: Income || Type: <class 'numpy.int64'> || Example: 137576 || number of unique values 105214
# feature: LoanAmount || Type: <class 'numpy.int64'> || Example: 209136 || number of unique values 138850
# feature: CreditScore || Type: <class 'numpy.int64'> || Example: 846 || number of unique values 550
# feature: MonthsEmployed || Type: <class 'numpy.int64'> || Example: 26 || number of unique values 120
# feature: NumCreditLines || Type: <class 'numpy.int64'> || Example: 2 || number of unique values 4
# feature: InterestRate || Type: <class 'numpy.float64'> || Example: 10.47 || number of unique values 2301
# feature: LoanTerm || Type: <class 'numpy.int64'> || Example: 60 || number of unique values 5
# ...

# %% [markdown]
# ### Testing dataset

# %%
list_features = df_test.columns
print('They are',len(list_features),'features in the dataset.')
print('----------------')
for f in list_features:
    print('feature:', f, '|| Type:', type(df_test[f][0]), '|| Example:', df_test[f][0], '|| number of unique values', len(df_test[f].unique()) )
# Out:
# They are 17 features in the dataset.
# ----------------
# feature: LoanID || Type: <class 'str'> || Example: CKV34LU7V7 || number of unique values 51070
# feature: Age || Type: <class 'numpy.int64'> || Example: 55 || number of unique values 52
# feature: Income || Type: <class 'numpy.int64'> || Example: 112656 || number of unique values 42461
# feature: LoanAmount || Type: <class 'numpy.int64'> || Example: 92393 || number of unique values 46088
# feature: CreditScore || Type: <class 'numpy.int64'> || Example: 581 || number of unique values 550
# feature: MonthsEmployed || Type: <class 'numpy.int64'> || Example: 113 || number of unique values 120
# feature: NumCreditLines || Type: <class 'numpy.int64'> || Example: 2 || number of unique values 4
# feature: InterestRate || Type: <class 'numpy.float64'> || Example: 23.54 || number of unique values 2301
# feature: LoanTerm || Type: <class 'numpy.int64'> || Example: 36 || number of unique values 5
# ...

# %% [markdown]
# ## Null Values

# %% [markdown]
# ### Null values in each column of the training dataset

# %%
null_counts = df.isnull().sum()
null_counts = null_counts[null_counts > 0]  

if null_counts.empty:
    print("No columns contain null values in the training dataset")
else:
    print("Columns with null values:")
    print(null_counts.to_string(header=False))
# Out:
# No columns contain null values in the training dataset

# %% [markdown]
# ### Null values in each column of the testing dataset

# %%
null_counts = df_test.isnull().sum()
null_counts = null_counts[null_counts > 0]  

if null_counts.empty:
    print("No columns contain null values in the testing dataset")
else:
    print("Columns with null values:")
    print(null_counts.to_string(header=False))
# Out:
# No columns contain null values in the testing dataset

# %% [markdown]
# ## Types of loan Pie chart

# %%
import seaborn as sns

loan_purpose_counts = df['LoanPurpose'].value_counts()

sns.set_theme(style="whitegrid")
colors = sns.color_palette("Pastel1", len(loan_purpose_counts))

plt.figure(figsize=(8, 6))
plt.pie(loan_purpose_counts, 
        labels=loan_purpose_counts.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=colors,
        wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'linestyle': 'solid'})

plt.title('Distribution of Loan Purposes', fontsize=16, fontweight='bold')
plt.axis('equal')  

plt.show()

# %% [markdown]
# ## Education Pie Chart Distribution

# %%
import seaborn as sns

loan_purpose_counts = df['Education'].value_counts()

sns.set_theme(style="whitegrid")
colors = sns.color_palette("Pastel1", len(loan_purpose_counts))

plt.figure(figsize=(8, 6))
plt.pie(loan_purpose_counts, 
        labels=loan_purpose_counts.index, 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=colors,
        wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'linestyle': 'solid'})

plt.title('Distribution of Education', fontsize=16, fontweight='bold')
plt.axis('equal')  

plt.show()

# %% [markdown]
# ## Summary of Categorical Columns

# %%
# selected_columns = df.select_dtypes(include='object').columns[:10]

# n_cols = 2
# n_rows = (len(selected_columns) + 1) // n_cols  

# print(selected_columns)

# # Set up the figure for subplots
# plt.figure(figsize=(15, 4 * n_rows))
# plt.suptitle("Top 10 Categorical Columns Distribution", fontsize=16)

# # Loop through each selected categorical column and create a subplot
# for idx, col in enumerate(selected_columns, 1):
#     plt.subplot(n_rows, n_cols, idx)
#     sns.countplot(data=df, x=col, order=df[col].value_counts().index)
#     plt.xticks(rotation=45)
#     plt.title(f"Distribution of {col}")

# # Adjust layout
# plt.tight_layout(rect=[0, 0, 1, 0.96])
# plt.show()

# %% [markdown]
# ## Distribution of Numerical Features

# %% [markdown]
# Visualize the distribution of numerical columns with histograms and density plots.

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns
numerical_columns = [col for col in numerical_columns if col != 'Default']

# Define subplot layout
n_cols = 2
n_rows = (len(numerical_columns) + 1) // n_cols  

# Set up the figure for subplots
plt.figure(figsize=(15, 4 * n_rows))
plt.suptitle("Numerical Features Distribution", fontsize=16)

# Loop through each numerical column and create a subplot
for idx, col in enumerate(numerical_columns, 1):
    plt.subplot(n_rows, n_cols, idx)
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## Outliers Detection using Boxplots

# %% [markdown]
# Use box plots to detect any outliers in numerical columns.

# %%
n_cols = 4
n_rows = (len(numerical_columns) + n_cols - 1) // n_cols 

plt.figure(figsize=(20, 5 * n_rows))  
plt.suptitle("Outliers Detection in Numerical Features (Excluding 'default')", fontsize=16)

# Loop through each numerical column and create a subplot
for idx, col in enumerate(numerical_columns, 1):
    plt.subplot(n_rows, n_cols, idx)
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.xlabel(col)

# Adjust layout with extra spacing
plt.tight_layout(rect=[0, 0, 1, 0.96], h_pad=3, w_pad=3)  
plt.show()

# %% [markdown]
# ## Validity Checks for Numerical Columns

# %% [markdown]
# Check if values in numerical columns are within expected ranges.

# %%
validity_checks = {
    'Age': (0, 100),
    'Income': (0, 500000),
    'LoanAmount': (0, 1000000),
    'CreditScore': (300, 850),
    'MonthsEmployed': (0, 480),
    'InterestRate': (0, 100),
    'LoanTerm': (0, 360),
    'DTIRatio': (0, 1)
}

print("\nValidity Checks for Numerical Columns:")
for col, (min_val, max_val) in validity_checks.items():
    if col in df.columns:
        invalid_data = df[(df[col] < min_val) | (df[col] > max_val)]
        print(f"\n{col} - Invalid values found:")
        print(invalid_data[[col]] if not invalid_data.empty else "None")
# Out:
# Validity Checks for Numerical Columns:
#
# Age - Invalid values found:
# None
#
# Income - Invalid values found:
# None
#
# LoanAmount - Invalid values found:
# None
#
# CreditScore - Invalid values found:
# None
#
# MonthsEmployed - Invalid values found:
# None
#
# InterestRate - Invalid values found:
# None
#
# LoanTerm - Invalid values found:
# None
#
# DTIRatio - Invalid values found:
# None

# %% [markdown]
# ## 7. Correlation Analysis

# %% [markdown]
# Generate a correlation matrix for numerical columns and visualize it with a heatmap.

# %%
# Correlation analysis using only numerical columns
print("\nCorrelation Analysis:")
numerical_df = df.select_dtypes(include=[np.number]) 
correlation_matrix = numerical_df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Analysis:

# %% [markdown]
# ## Overview of the Target Variable

# %% [markdown]
# First, let’s check its data type, unique values, and distribution. This will help us identify if it’s a classification (categorical target) or regression (continuous target) problem.

# %%
target_column = df.columns[-1]
print(f"Target Variable: {target_column}")

# Check the unique values in the target column
print(f"Unique values in {target_column}: {df[target_column].unique()}")
print("\nDistribution of Target Variable:")
print(df[target_column].value_counts())
# Out:
# Target Variable: Default
# Unique values in Default: [0 1]
#
# Distribution of Target Variable:
# Default
# 0    180524
# 1     23753
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution Plot

# %% [markdown]
# Visualizing distribution of the target variable. If it's continuous, use a histogram; if it’s categorical, use a bar chart.

# %%
plt.figure(figsize=(8, 5))
if df[target_column].dtype == 'object' or len(df[target_column].unique()) < 10:
    sns.countplot(x=target_column, data=df)
    plt.title(f"Distribution of {target_column}")
else:
    sns.histplot(df[target_column], kde=True)
    plt.title(f"Histogram of {target_column}")
plt.show()

# %% [markdown]
# ## Class Imbalance Check (for Categorical Targets)

# %% [markdown]
# Checking for class imbalance. Imbalanced data may affect model performance and require specific handling techniques.

# %%
if df[target_column].dtype == 'object' or len(df[target_column].unique()) < 10:
    class_counts = df[target_column].value_counts(normalize=True)
    print(f"Class Distribution in {target_column}:\n{class_counts}")
# Out:
# Class Distribution in Default:
# Default
# 0    0.883722
# 1    0.116278
# Name: proportion, dtype: float64

# %% [markdown]
# ## Relationship Between Target and Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_columns = df.select_dtypes(include=[np.number]).columns
top_numerical = numerical_columns  

n_cols = 2
n_rows = (len(top_numerical) + 1) // n_cols  

plt.figure(figsize=(15, 5 * n_rows))
plt.suptitle("Numerical vs Target Analysis", fontsize=16)

for idx, col in enumerate(top_numerical, 1):
    plt.subplot(n_rows, n_cols, idx)
    sns.boxplot(x=target_column, y=col, data=df)
    plt.title(f"Relationship between {target_column} and {col}")
    plt.xlabel(target_column)
    plt.ylabel(col)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

categorical_columns = df.select_dtypes(include='object').columns

filtered_categorical = [col for col in categorical_columns if col != target_column and df[col].nunique() <= 10]

n_cols = 2
n_rows = (len(filtered_categorical) + 1) // n_cols  

plt.figure(figsize=(15, 5 * n_rows))
plt.suptitle("Categorical vs Target Analysis", fontsize=16)

# Plot each categorical column against the target in a subplot
for idx, col in enumerate(filtered_categorical, 1):
    plt.subplot(n_rows, n_cols, idx)
    sns.countplot(data=df, x=col, hue=target_column)
    plt.title(f"{col} distribution across {target_column} values")
    plt.xticks(rotation=45)
    plt.xlabel(col)
    plt.ylabel("Count")

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Label Encoding Training data and Testing data

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
obj_col = ['HasCoSigner','LoanPurpose','HasDependents', 'HasMortgage','MaritalStatus', 'EmploymentType', 'Education']

# %%
for col in obj_col:
    df[col] = le.fit_transform(df[col])

df = df.drop(['LoanID'], axis=1)

# %%
for col in obj_col:
    df_test[col] = le.fit_transform(df_test[col])

df_test = df_test.drop(['LoanID'], axis=1)

# %% [markdown]
# ## Splitting training data into dependent and independent variables

# %%
X = df.drop(['Default'], axis=1)
y = df['Default']

# %% [markdown]
# # Model Training

# %% [markdown]
# ## RandomForest

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

sample_submission = pd.read_csv('sample_submission.csv')

rf_param_grid = {
    'n_estimators': [100,],
    'max_depth': [10, 20, None],
    'min_samples_split': [2],
    'min_samples_leaf': [1,],
    'random_state': [42]
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Initialize RandomForestClassifier
rf = RandomForestClassifier()

rf_random_search = RandomizedSearchCV(
    rf, rf_param_grid, n_iter=1, cv=2, random_state=42, n_jobs=-1, scoring='accuracy'
)

rf_random_search.fit(X_train, y_train)
best_rf_model = rf_random_search.best_estimator_

y_pred = best_rf_model.predict(X_test)

# %% [markdown]
# ### Model Evaluations

# %%
train_accuracy = accuracy_score(y_train, best_rf_model.predict(X_train))
print("Training Accuracy:", train_accuracy)

train_class_report = classification_report(y_train, best_rf_model.predict(X_train))
print("Classification Report:\n", train_class_report)
# Out:
# Training Accuracy: 0.8887061296154876
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94    135381
#            1       0.95      0.05      0.09     17826
#
#     accuracy                           0.89    153207
#    macro avg       0.92      0.52      0.51    153207
# weighted avg       0.90      0.89      0.84    153207

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Saving the Predictions

# %%
df_test_pred = best_rf_model.predict(df_test)

submission_df = sample_submission.copy()
submission_df['Default'] = df_test_pred  

submission_df.to_csv('RandomForest_predictions.csv', index=False)
print("Predictions saved to 'RandomForest_predictions.csv'")
# Out:
# Predictions saved to 'RandomForest_predictions.csv'

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

sample_submission = pd.read_csv('sample_submission.csv')

xgb_param_grid = {
    'n_estimators': [100, 200,],
    'max_depth': [3, 4],
    'learning_rate': [0.01, 0.05],
    'subsample': [0.7, 0.8,],
    'colsample_bytree': [0.7, 0.8],
    'eval_metric': ['logloss'],  
    'random_state': [42]
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(
    xgb, param_distributions=xgb_param_grid, n_iter=2, cv=2, random_state=42, n_jobs=-1, scoring='roc_auc'
)

random_search.fit(X, y)

xgb_best = random_search.best_estimator_

# Predict on df_test (assuming df_test is already defined and preprocessed)
df_test_pred = xgb_best.predict(df_test)

# Evaluate on the training set 
train_pred = xgb_best.predict(X)
train_accuracy = accuracy_score(y, train_pred)
train_class_report = classification_report(y, train_pred)

# %% [markdown]
# ### Model Evaluation

# %%
print("Training Accuracy:", train_accuracy)
print("Classification Report:\n", train_class_report)
# Out:
# Training Accuracy: 0.8868007656270652
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94    180524
#            1       0.65      0.06      0.11     23753
#
#     accuracy                           0.89    204277
#    macro avg       0.77      0.53      0.52    204277
# weighted avg       0.86      0.89      0.84    204277

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion matrix
cm = confusion_matrix(y, train_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=['Predicted No Default', 'Predicted Default'], yticklabels=['Actual No Default', 'Actual Default'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Saving the Model Predictions

# %%
submission_df = sample_submission.copy()
submission_df['Default'] = df_test_pred  

submission_df.to_csv('XGBClassifier_predictions_random_search.csv', index=False)
print("Predictions saved to 'XGBClassifier_predictions_random_search.csv'")
# Out:
# Predictions saved to 'XGBClassifier_predictions_random_search.csv'

# %% [markdown]
# ## Catboost

# %%
! pip install catboost

# %%
# from catboost import CatBoostClassifier
# from sklearn.model_selection import RandomizedSearchCV

# # Load sample_submission to get LoanID
# sample_submission = pd.read_csv('sample_submission.csv')

# # Define expanded parameter grid for CatBoostClassifier
# cat_params = {
#     'iterations': [100, 300, 500, 700, 1000],
#     'learning_rate': [0.01, 0.05, 0.1, 0.2],
#     'depth': [4, 6, 8, 10, 12],
#     'l2_leaf_reg': [1, 3, 5, 7, 9], 
#     'border_count': [32, 64, 128],  
#     'random_seed': [42]
# }

# # Initialize CatBoostClassifier
# cat = CatBoostClassifier(verbose=0)

# # Use RandomizedSearchCV to find the best parameters
# cat_random = RandomizedSearchCV(
#     cat, cat_params, n_iter=20, cv=3, random_state=42, n_jobs=-1
# )

# cat_best = cat_random.fit(X, y).best_estimator_
# df_test_pred = cat_best.predict(df_test)

# submission_df = sample_submission.copy()
# submission_df['Default'] = df_test_pred  # Assign predictions to 'Default' column

# # Save to CSV file
# submission_df.to_csv('CatBoostClassifier_predictions.csv', index=False)

# print("Predictions saved to 'CatBoostClassifier_predictions.csv'")


# second best model less time consuming

# %%
# import seaborn as sns
# from catboost import CatBoostClassifier
# from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
# from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix

# # Load sample_submission to get LoanID
# sample_submission = pd.read_csv('sample_submission.csv')

# # Define expanded parameter grid for CatBoostClassifier with more details
# cat_params = {
#     'iterations': [100, 300, 500, 700, 1000, 1200],
#     'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
#     'depth': [4, 6, 8, 10, 12, 15],
#     'l2_leaf_reg': [1, 3, 5, 7, 9, 10],
#     'border_count': [32, 64, 128, 256],
#     'bagging_temperature': [0.0, 0.2, 0.5, 1.0],
#     'max_bin': [32, 64, 128],
#     'score_function': ['Cosine', 'L2'],
#     'random_seed': [42]
# }

# cat = CatBoostClassifier(verbose=0)

# # Use StratifiedKFold for balanced cross-validation folds
# cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# # RandomizedSearchCV to find the best parameters with more iterations and additional metrics
# cat_random = RandomizedSearchCV(
#     cat, cat_params, n_iter=10, cv=cv, random_state=42, n_jobs=-1, scoring='roc_auc'
# )

# # Fit the RandomizedSearchCV
# cat_best = cat_random.fit(X, y).best_estimator_

# # Predict on the test set
# df_test_pred = cat_best.predict(df_test)
# df_test_prob = cat_best.predict_proba(df_test)[:, 1]  # Probabilities for AUC

# # Evaluation on training set (optional but informative)
# train_pred = cat_best.predict(X)
# train_accuracy = accuracy_score(y, train_pred)
# train_auc = roc_auc_score(y, cat_best.predict_proba(X)[:, 1])

# %% [markdown]
# ### Model Evaluation

# %%
# print("Training Accuracy:", train_accuracy)
# print("Training AUC:", train_auc)
# print("Classification Report:\n", classification_report(y, train_pred))

# %% [markdown]
# ### Confusion Matrix

# %%
# # Confusion Matrix
# cm = confusion_matrix(y, train_pred)
# print("Confusion Matrix:\n", cm)

# # Plot the Confusion Matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=['Predicted No Default', 'Predicted Default'], yticklabels=['Actual No Default', 'Actual Default'])
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.title('Confusion Matrix')
# plt.show()

# %% [markdown]
# ### Saving the Model Predictions

# %%
# submission_df = sample_submission.copy()
# submission_df['Default'] = df_test_pred  

# submission_df.to_csv('CatBoostClassifier_predictions.csv', index=False)
# print("Predictions saved to 'CatBoostClassifier_predictions.csv'")

# %% [markdown]
# ## Logistic regression

# %%
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

sample_submission = pd.read_csv('sample_submission.csv')

log_reg_params = {
    'C': [0.1, 1, 10],  
    'penalty': ['l2'],  
    'solver': ['liblinear', 'saga'],  
    'max_iter': [100, 200],  
    'random_state': [42]
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

log_reg = LogisticRegression()
log_reg_random = RandomizedSearchCV(log_reg, log_reg_params, n_iter=3, cv=2, random_state=42)
log_reg_best = log_reg_random.fit(X_train, y_train).best_estimator_

y_pred = log_reg_best.predict(X_test)

# Evaluate on training set (optional but informative)
train_pred = log_reg_best.predict(X_train)
train_accuracy = accuracy_score(y_train, train_pred)
train_class_report = classification_report(y_train, train_pred)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# ### Training Metrics

# %%
print("Training Accuracy:", train_accuracy)
print("Classification Report:\n", train_class_report)
print("Confusion Matrix:\n", cm)
# Out:
# Training Accuracy: 0.8838499546365375
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94    135381
#            1       0.70      0.00      0.01     17826
#
#     accuracy                           0.88    153207
#    macro avg       0.79      0.50      0.47    153207
# weighted avg       0.86      0.88      0.83    153207
#
# Confusion Matrix:
#  [[179779    745]
#  [ 22379   1374]]

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=['Predicted No Default', 'Predicted Default'], yticklabels=['Actual No Default', 'Actual Default'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Saving the Predictions file

# %%
df_test_pred = log_reg_best.predict(df_test)

submission_df = sample_submission.copy()
submission_df['Default'] = df_test_pred  
submission_df.to_csv('LogisticRegression_predictions.csv', index=False)

print("Predictions saved to 'LogisticRegression_predictions.csv'")
# Out:
# Predictions saved to 'LogisticRegression_predictions.csv'
